# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Akhil pokuri Atyeti/stack-overflow-developer-survey-2019/survey_results_public.csv')

# %%
data.head(4)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
# 3                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# ...

# %%
data.tail(10)  ## for last 10 items
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
data.shape
# Out:
# (88883, 85)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
data.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.loc[12]
# Out:
# Respondent                                                     13
# MainBranch                         I am a developer by profession
# Hobbyist                                                      Yes
# OpenSourcer     Less than once a month but more than once per ...
# OpenSource      OSS is, on average, of HIGHER quality than pro...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                            White or of European descent
# Dependents                                                    Yes
# SurveyLength                                Appropriate in length
# SurveyEase                                                   Easy
# Name: 12, Length: 85, dtype: object

# %%
data.loc[12:44]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 12          13                     I am a developer by profession      Yes
# 13          14                     I am a developer by profession      Yes
# 14          15             I am a student who is learning to code      Yes
# 15          16                     I am a developer by profession      Yes
# 16          17                     I am a developer by profession      Yes
# 17          18  I am not primarily a developer, but I write co...      Yes
# 18          19                     I am a developer by profession      Yes
# 19          20  I am not primarily a developer, but I write co...       No
# 20          21                        I code primarily as a hobby      Yes
# 21          22                     I am a developer by profession      Yes
# 22          23                     I am a developer by profession      Yes
# ...

# %%
data.loc[40:47:3] ## jump by 3
# Out:
#     Respondent                      MainBranch Hobbyist  \
# 40          41  I am a developer by profession      Yes
# 43          44  I am a developer by profession      Yes
# 46          47  I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 40     Less than once per year
# 43  Once a month or more often
# 46     Less than once per year
#
#                                            OpenSource          Employment  \
# 40  OSS is, on average, of HIGHER quality than pro...  Employed part-time
# 43  The quality of OSS and closed source software ...  Employed full-time
# 46  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#           Country         Student                                    EdLevel  \
# 40       Malaysia  Yes, full-time   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 43        Germany              No   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
data[['UnitTests','PurchaseWhat']]
# Out:
#                            UnitTests                   PurchaseWhat
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2          No, but I think we should  I have little or no influence
# 3          No, but I think we should  I have little or no influence
# 4      Yes, it's part of our process  I have little or no influence
# ...                              ...                            ...
# 88878                            NaN                            NaN
# 88879                            NaN                            NaN
# 88880                            NaN                            NaN
# 88881                            NaN                            NaN
# 88882                            NaN                            NaN
#
# [88883 rows x 2 columns]

# %%
data.loc[[12,13,14],['LanguageWorkedWith','Country','OrgSize']]
# Out:
#                                    LanguageWorkedWith        Country  \
# 12  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...  United States
# 13                                                C++        Germany
# 14  Assembly;Bash/Shell/PowerShell;C;C++;HTML/CSS;...          India
#
#                  OrgSize
# 12    10 to 19 employees
# 13  100 to 499 employees
# 14                   NaN

# %%
data.loc[22:29, 'EduOther' : 'CareerSat']  # slicing
# Out:
#                                              EduOther  \
# 22  Taken an online course in programming or softw...
# 23  Taken an online course in programming or softw...
# 24  Taken an online course in programming or softw...
# 25  Taught yourself a new language, framework, or ...
# 26  Taken an online course in programming or softw...
# 27  Taken an online course in programming or softw...
# 28  Taken an online course in programming or softw...
# 29  Taught yourself a new language, framework, or ...
#
#                      OrgSize  \
# 22  10,000 or more employees
# 23        10 to 19 employees
# 24             2-9 employees
# 25  10,000 or more employees
# 26                       NaN
# 27             2-9 employees
# 28  10,000 or more employees
# 29  1,000 to 4,999 employees
#
#                                               DevType YearsCode Age1stCode  \
# 22                              Developer, full-stack         3         19
# ...

# %%
data.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
# setting index

index_data = data.set_index('Respondent').head(5)
index_data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
index_data.iloc[4]['MainBranch' : 'Trans']
# Out:
# MainBranch                          I am a developer by profession
# Hobbyist                                                       Yes
# OpenSourcer                             Once a month or more often
# OpenSource       OSS is, on average, of HIGHER quality than pro...
# Employment                                      Employed full-time
#                                        ...
# WelcomeChange              Just as welcome now as I felt last year
# SONewContent     Tech meetups or events in your area;Courses on...
# Age                                                           30.0
# Gender                                                         Man
# Trans                                                           No
# Name: 5, Length: 79, dtype: object

# %%
d ={
    'name': ['AKHI','sai','sandeep'],
    'company' : ['WIPRO','TCS','ATYE']
}
d
# Out:
# {'name': ['AKHI', 'sai', 'sandeep'], 'company': ['WIPRO', 'TCS', 'ATYE']}

# %%
A = pd.DataFrame(d)

# %%
A
# Out:
#       name company
# 0     AKHI   WIPRO
# 1      sai     TCS
# 2  sandeep    ATYE

# %%
c=(A['name'] == 'sai')  #filtering
A[c]
# Out:
#   name company
# 1  sai     TCS

# %%
A[A['name'] == 'sai']
# Out:
#   name company
# 1  sai     TCS

# %%
data['ConvertedComp'].max()
# Out:
# 2000000.0

# %%
# salaries of top 10

high_salary = data[data['ConvertedComp'] > 600000][['Respondent','ConvertedComp']].head(10)
high_salary.sort_values('Respondent')
# Out:
#      Respondent  ConvertedComp
# 31           32      1100000.0
# 57           58      2000000.0
# 101         102      2000000.0
# 127         128      1000000.0
# 153         155       962424.0
# 155         157       960000.0
# 164         166      2000000.0
# 243         245       649536.0
# 260         262       864000.0
# 271         273      1000000.0

# %%
high_salary = data[data['ConvertedComp'] > 600000][[ 'ConvertedComp']].head(10)
high_salary.sort_values('ConvertedComp')
# Out:
#      ConvertedComp
# 243       649536.0
# 260       864000.0
# 155       960000.0
# 153       962424.0
# 127      1000000.0
# 271      1000000.0
# 31       1100000.0
# 57       2000000.0
# 101      2000000.0
# 164      2000000.0

# %%
# max salary by index
high_salary.idxmax()
# Out:
# ConvertedComp    57
# dtype: int64

# %%
data[data['ConvertedComp'] > 700000].head(3)
# Out:
#      Respondent                      MainBranch Hobbyist  \
# 31           32  I am a developer by profession       No
# 57           58  I am a developer by profession      Yes
# 101         102  I am a developer by profession       No
#
#                     OpenSourcer  \
# 31                        Never
# 57   Once a month or more often
# 101                       Never
#
#                                             OpenSource          Employment  \
# 31   The quality of OSS and closed source software ...  Employed full-time
# 57   OSS is, on average, of LOWER quality than prop...  Employed full-time
# 101  The quality of OSS and closed source software ...  Employed full-time
#
#            Country Student                                   EdLevel  \
# 31   United States      No                          Associate degree
# 57   United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
# ...

# %%
fl = data[['Respondent','ConvertedComp','LanguageWorkedWith','DatabaseWorkedWith']]
fl
# Out:
#        Respondent  ConvertedComp  \
# 0               1            NaN
# 1               2            NaN
# 2               3         8820.0
# 3               4        61000.0
# 4               5            NaN
# ...           ...            ...
# 88878       88377            NaN
# 88879       88601            NaN
# 88880       88802            NaN
# 88881       88816            NaN
# 88882       88863            NaN
#
#                                       LanguageWorkedWith  \
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# ...

# %%
countries = ['united kingdom','India','Canada']
filt = data['Country'].isin(countries)

# %%
data.loc[filt, 'Country']
# Out:
# 5        Canada
# 7         India
# 9         India
# 11       Canada
# 14        India
#           ...
# 88852     India
# 88853     India
# 88855    Canada
# 88864     India
# 88878    Canada
# Name: Country, Length: 12456, dtype: object

# %%
# string methodS

fl_lan = data['LanguageWorkedWith'].str.contains('Python', na =False)
data.loc[fl_lan, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
data.value_counts('YearsCodePro').std()
# Out:
# 2115.237134191161

# %%
[x.upper() for x in data.columns]  #uppder letters of column names, (.lower())
# Out:
# ['RESPONDENT',
#  'MAINBRANCH',
#  'HOBBYIST',
#  'OPENSOURCER',
#  'OPENSOURCE',
#  'EMPLOYMENT',
#  'COUNTRY',
#  'STUDENT',
#  'EDLEVEL',
#  'UNDERGRADMAJOR',
#  'EDUOTHER',
#  'ORGSIZE',
#  'DEVTYPE',
#  'YEARSCODE',
#  'AGE1STCODE',
#  'YEARSCODEPRO',
#  'CAREERSAT',
#  'JOBSAT',
#  'MGRIDIOT',
#  'MGRMONEY',
#  'MGRWANT',
#  'JOBSEEK',
#  'LASTHIREDATE',
#  'LASTINT',
#  'FIZZBUZZ',
#  'JOBFACTORS',
#  'RESUMEUPDATE',
#  'CURRENCYSYMBOL',
#  'CURRENCYDESC',
#  'COMPTOTAL',
#  'COMPFREQ',
#  'CONVERTEDCOMP',
#  'WORKWEEKHRS',
#  'WORKPLAN',
#  'WORKCHALLENGE',
#  'WORKREMOTE',
#  'WORKLOC',
#  'IMPSYN',
#  'CODEREV',
#  'CODEREVHRS',
#  'UNITTESTS',
#  'PURCHASEHOW',
#  'PURCHASEWHAT',
#  'LANGUAGEWORKEDWITH',
#  'LANGUAGEDESIRENEXTYEAR',
#  'DATABASEWORKEDWITH',
#  'DATABASEDESIRENEXTYEAR',
#  'PLATFORMWORKEDWITH',
#  'PLATFORMDESIRENEXTYEAR',
#  'WEBFRAMEWORKEDWITH',
#  'WEBFRAMEDESIRENEXTYEAR',
#  'MISCTECHWORKEDWITH',
#  'MISCTECHDESIRENEXTYEAR',
#  'DEVENVIRON',
# ...

# %%
# STRING REPLACE METHOD RO REMOVE SYMBOLS AND SPACING and also used to to change values

data.columns.str.replace('_', '')
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# renaming the column name

high_salary.rename(columns ={'ConvertedComp' : 'High_amount'})
# Out:
#      Respondent  High_amount
# 31           32    1100000.0
# 57           58    2000000.0
# 101         102    2000000.0
# 127         128    1000000.0
# 153         155     962424.0
# 155         157     960000.0
# 164         166    2000000.0
# 243         245     649536.0
# 260         262     864000.0
# 271         273    1000000.0

# %%
data.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country   Student  \
# 0  Not employed, and not looking for work  United Kingdom  fulltime
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school   dataengineer
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
# Updating values in fields

data.loc[0,['Student','UndergradMajor']] = ['fulltime','dataengineer']
data.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0        fulltime                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
# AT -- method for onely single values not for multiple

data.at[1,'UndergradMajor'] = 'IT'
data.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0        fulltime                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
data[data['UndergradMajor'] == 'dataengineer']
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country   Student  \
# 0  Not employed, and not looking for work  United Kingdom  fulltime
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school   dataengineer
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
fl.head(3)
# Out:
#    Respondent  ConvertedComp               LanguageWorkedWith  \
# 0           1            NaN  HTML/CSS;Java;JavaScript;Python
# 1           2            NaN              C++;HTML/CSS;Python
# 2           3         8820.0                         HTML/CSS
#
#   DatabaseWorkedWith
# 0             SQLite
# 1                NaN
# 2         PostgreSQL

# %%
fl['LanguageWorkedWith'] =fl['LanguageWorkedWith'].str.lower()
fl.head()
# Out:
# C:\Users\AkhilPokuri\AppData\Local\Temp\ipykernel_15324\2353303210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fl['LanguageWorkedWith'] =fl['LanguageWorkedWith'].str.lower()
#    Respondent  ConvertedComp                           LanguageWorkedWith  \
# 0           1            NaN              html/css;java;javascript;python
# 1           2            NaN                          c++;html/css;python
# 2           3         8820.0                                     html/css
# 3           4        61000.0                          c;c++;c#;python;sql
# 4           5            NaN  c++;html/css;java;javascript;python;sql;vba
#
#                                  DatabaseWorkedWith
# ...

# %%
fl.applymap(str.lower)  # for entair data to lower characters

# %%
fl['DatabaseWorkedWith'].replace({'NAN' :'DB'},inplace = True)
fl
# Out:
# C:\Users\AkhilPokuri\AppData\Local\Temp\ipykernel_15324\2133536949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fl['DatabaseWorkedWith'].replace({'NAN' :'DB'},inplace = True)
#        Respondent  ConvertedComp  \
# 0               1            NaN
# 1               2            NaN
# 2               3         8820.0
# 3               4        61000.0
# 4               5            NaN
# ...           ...            ...
# 88878       88377            NaN
# 88879       88601            NaN
# 88880       88802            NaN
# 88881       88816            NaN
# 88882       88863            NaN
#
#                                       LanguageWorkedWith  \
# 0                        html/css;java;javascript;python
# 1                                    c++;html/css;python
# ...

# %%
fl['DatabaseWorkedWith'].fillna('DB')
# Out:
# 0                                                  SQLite
# 1                                                      DB
# 2                                              PostgreSQL
# 3                                            MySQL;SQLite
# 4        Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#                                ...
# 88878                                     Firebase;SQLite
# 88879                                                  DB
# 88880                                                  DB
# 88881                                                  DB
# 88882         DynamoDB;MariaDB;Microsoft SQL Server;MySQL
# Name: DatabaseWorkedWith, Length: 88883, dtype: object

# %%
fl['LanguageWorkedWith'].fillna('basic programming',inplace =True)
# Out:
# C:\Users\AkhilPokuri\AppData\Local\Temp\ipykernel_15324\2209354813.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fl['LanguageWorkedWith'].fillna('basic programming',inplace =True)
# C:\Users\AkhilPokuri\AppData\Local\Temp\ipykernel_15324\2209354813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
fl['ConvertedComp'].fillna(0,inplace = True)
# Out:
# C:\Users\AkhilPokuri\AppData\Local\Temp\ipykernel_15324\187738949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fl['ConvertedComp'].fillna(0,inplace = True)

# %%
fl.head(7)
# Out:
#    Respondent  ConvertedComp                           LanguageWorkedWith  \
# 0           1            0.0              html/css;java;javascript;python
# 1           2            0.0                          c++;html/css;python
# 2           3         8820.0                                     html/css
# 3           4        61000.0                          c;c++;c#;python;sql
# 4           5            0.0  c++;html/css;java;javascript;python;sql;vba
# 5           6       366420.0                                   java;r;sql
# 6           7            0.0                          html/css;javascript
#
#                                  DatabaseWorkedWith
# 0                                            SQLite
# 1                                                DB
# 2                                        PostgreSQL
# 3                                      MySQL;SQLite
# 4  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 5                                MongoDB;PostgreSQL
# ...

# %%
# Deleating a row

fl.drop(index =fl[fl['ConvertedComp'] == 0.0].index)  # to save changes inplace = True
# Out:
#        Respondent  ConvertedComp  \
# 2               3         8820.0
# 3               4        61000.0
# 5               6       366420.0
# 8               9        95179.0
# 9              10        13293.0
# ...           ...            ...
# 88325       88878       130000.0
# 88326       88879        82488.0
# 88328       88881        68745.0
# 88329       88882       588012.0
# 88330       88883        22915.0
#
#                                       LanguageWorkedWith  \
# 2                                               html/css
# 3                                    c;c++;c#;python;sql
# 5                                             java;r;sql
# 8      bash/shell/powershell;c#;html/css;javascript;p...
# 9                          c#;go;javascript;python;r;sql
# ...                                                  ...
# 88325               html/css;javascript;scala;typescript
# 88326                   bash/shell/powershell;c++;python
# ...

# %%
data.head(1)
# Out:
#    Respondent                              MainBranch Hobbyist OpenSourcer  \
# 0           1  I am a student who is learning to code      Yes       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
#
#                                Employment         Country   Student  \
# 0  Not employed, and not looking for work  United Kingdom  fulltime
#
#                      EdLevel UndergradMajor  \
# 0  Primary/elementary school   dataengineer
#
#                                             EduOther OrgSize DevType  \
# 0  Taught yourself a new language, framework, or ...     NaN     NaN
#
#   YearsCode Age1stCode YearsCodePro CareerSat JobSat MgrIdiot MgrMoney  \
# 0         4         10          NaN       NaN    NaN      NaN      NaN
#
#   MgrWant JobSeek LastHireDate LastInt FizzBuzz JobFactors ResumeUpdate  \
# 0     NaN     NaN          NaN     NaN      NaN        NaN          NaN
#
# ...

# %%
data.sort_values(by = ['YearsCode', 'Age1stCode'], ascending = [True, False]).head(3)
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 4838        4861             I am a student who is learning to code      Yes
# 8564        8602  I am not primarily a developer, but I write co...       No
# 8655        8693             I am a student who is learning to code      Yes
#
#                   OpenSourcer  \
# 4838  Less than once per year
# 8564                    Never
# 8655                    Never
#
#                                              OpenSource  \
# 4838  OSS is, on average, of HIGHER quality than pro...
# 8564  The quality of OSS and closed source software ...
# 8655                                                NaN
#
#                                              Employment     Country  \
# 4838                                 Employed full-time  Azerbaijan
# 8564  Independent contractor, freelancer, or self-em...      Taiwan
# 8655             Not employed, and not looking for work      Taiwan
#
# ...

# %%
fl.sort_index()

fl['ConvertedComp'].sort_values(ascending = False)
# Out:
# 12860    2000000.0
# 88162    2000000.0
# 70630    2000000.0
# 83375    2000000.0
# 25376    2000000.0
#            ...
# 43007          0.0
# 43013          0.0
# 43016          0.0
# 43017          0.0
# 88882          0.0
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
data.sort_values(by = 'Country')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 39018       39258  I am a developer by profession      Yes
# 62723       63129  I am a developer by profession      Yes
# 85185       85715  I am a developer by profession       No
# 50437       50767  I am a developer by profession       No
# 88340        2782                             NaN      Yes
# ...           ...                             ...      ...
# 88873       88062                             NaN       No
# 88874       88076                             NaN       No
# 88879       88601                             NaN       No
# 88880       88802                             NaN       No
# 88881       88816                             NaN       No
#
#                    OpenSourcer  \
# 39018  Less than once per year
# 62723                    Never
# 85185  Less than once per year
# 50437  Less than once per year
# 88340  Less than once per year
# ...                        ...
# ...

# %%
# large and smallest values in a cloumn

fl['ConvertedComp'].nlargest(10)
fl['ConvertedComp'].nsmallest(1)
# Out:
# 0    0.0
# Name: ConvertedComp, dtype: float64

# %%
#aggregation function by column

fl['ConvertedComp'].describe()
# Out:
# count    8.888300e+04
# mean     7.983194e+04
# std      2.334190e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.024400e+04
# 75%      7.050000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
data['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
data['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
# for % sign 

data['SocialMedia'].value_counts(normalize = True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
# groupby
d_g = data.groupby(['Country'])
d_g.get_group('India')
# Out:
# C:\Users\AkhilPokuri\AppData\Local\Temp\ipykernel_15324\306326917.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   d_g.get_group('India')
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# ...

# %%
d_g['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: count, Length: 1220, dtype: int64

# %%
d_g['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
data[data['Country'] == 'India']
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
d_g['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
data_country = data['Country'].value_counts()
data_country
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_used_python = d_g['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum()).head(10)
country_used_python
# Out:
# Country
# Afghanistan              8
# Albania                 23
# Algeria                 40
# Andorra                  0
# Angola                   2
# Antigua and Barbuda      0
# Argentina              191
# Armenia                 28
# Australia              790
# Austria                338
# Name: LanguageWorkedWith, dtype: int64

# %%
pd.concat(['data_country','country_used_python'], axis = 'columns', sort = False)

# %%
data.dtypes.head(40)
# Out:
# Respondent          int64
# MainBranch         object
# Hobbyist           object
# OpenSourcer        object
# OpenSource         object
# Employment         object
# Country            object
# Student            object
# EdLevel            object
# UndergradMajor     object
# EduOther           object
# OrgSize            object
# DevType            object
# YearsCode          object
# Age1stCode         object
# YearsCodePro       object
# CareerSat          object
# JobSat             object
# MgrIdiot           object
# MgrMoney           object
# MgrWant            object
# JobSeek            object
# LastHireDate       object
# LastInt            object
# FizzBuzz           object
# JobFactors         object
# ResumeUpdate       object
# CurrencySymbol     object
# CurrencyDesc       object
# CompTotal         float64
# CompFreq           object
# ConvertedComp     float64
# WorkWeekHrs       float64
# WorkPlan           object
# WorkChallenge      object
# ...

# %%
data['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
data['YearsCode'].replace('Less than 1 year', 0 , inplace =True)
data['YearsCode'].replace('More than 50 years', 0 , inplace =True)
data['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', '29', '44',
#        '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
# data type convertion to float

data['YearsCode'] = data['YearsCode'].astype(float)

data['YearsCode'].unique()
# Out:
# array([ 4., nan,  3., 16., 13.,  6.,  8., 12.,  2.,  5., 17., 10., 14.,
#        35.,  7.,  0., 30.,  9., 26., 40., 19., 15., 20., 28., 25.,  1.,
#        22., 11., 33., 50., 41., 18., 34., 24., 23., 42., 27., 21., 36.,
#        32., 39., 38., 31., 37., 29., 44., 45., 48., 46., 43., 47., 49.])

# %%
data['YearsCode'].mean()
# Out:
# 11.589040005458392

# %%
# DATE TIME SERIES 

data['date'] = pd.to_datetime(df['date'], format = '%y-%m-%d %i-%p')

# %%
filters = (data['date'] >= pd.to_datetime('2019=01-01')) & (df['date'] < pd.to_datetime('2020-01-01'))
df.loc[filters]

# %%
date['2020-01-01']['High'].max

0r

high = data['High'].resample('D').max()              #D- day, W- week, M- month, Y- year
high['2020-01-01']

# %%
data.resample('W').agg({'Close':'mean', 'High' : 'max', 'Low' : 'min', 'Volume' : 'sum'}]

# %%
# saving a file

data.to_excel('path.xlsx')
data.to_csv('path.csv')
data.to_excel('path.tsv', sep = '\t')

# %%
# DATA BASE

from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://dbpass@localhost:5432/sample_db')

# %%
india_df.to_sql('sample_table', engine, if_exist = 'replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index_col = 'Respondent')

# %%
sql_df.head()
