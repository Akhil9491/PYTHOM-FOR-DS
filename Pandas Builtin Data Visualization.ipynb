# %%
# Importing required packages
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
# loding data files
df1=pd.read_csv('C:/Users/AkhilPokuri/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df1.csv',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('C:/Users/AkhilPokuri/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3=pd.read_csv('C:/Users/AkhilPokuri/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df3.csv')
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
## data visualization 
## using pandas Data Frames ploting the historic plot
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
## plot hist using pandas in another type
df1['A'].plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# pandas area plot
df2.plot(kind='area',alpha=0.4,xlabel='its a area plot for data file df2')
#df2.plot.area()
# Out:
# <Axes: xlabel='its a area plot for data file df2'>

# %%
## pandas barplot
df2.plot(kind='bar')# stacked=false
df2.plot(kind='bar',stacked=True,xlabel='values',title='Barplt')
# Out:
# <Axes: title={'center': 'Barplt'}, xlabel='values'>

# %%
## stacked in pandas abr plot
df2.plot.bar(stacked=False)
# Out:
# <Axes: >

# %%
## line graph
# the df1 followed by time frame index so on x passing index and in y passin g cloumns

df1['B'].plot.line()
df1.plot.line(y='B')
df1.plot(kind='line',y='C',figsize=(9,5))

#df1.plot.line(x=df1.index,y='B')
# Out:
# <Axes: >

# %%
## scatter plot with pandas

df1.plot(kind='scatter',x='A',y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
## scatter plot with 3dimensional, Argument c by color.
df1.plot(kind='scatter',x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
## 3 dimensional argument by size 's' and multiplies to see big 

df1.plot(kind='scatter',x='A',y='B',s=df1['C']*20)
# Out:
# C:\Users\AkhilPokuri\anaconda3\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
## box plot in pandas

df1.plot.box()
df1.plot(kind='box',column='A')
# Out:
# <Axes: >

# %%
#hexbin plot
df1.plot.hexbin(x='A',y='B')
df1.plot.hexbin(x='A',y='B',gridsize=10, title= 'plot with size')
df1.plot(kind='hexbin',x='C',y='A', gridsize=25,cmap='coolwarm')
# Out:
# <Axes: xlabel='C', ylabel='A'>

# %%
## KDE -- Kernal density estimation in pandas

df2['c'].plot.kde()
df2.plot(kind='kde',cmap='coolwarm',figsize=(6,4),title='kde with legend')
df2.plot(kind='kde',grid=True,alpha=0.6,title="with grid's and legend")
# Out:
# <Axes: title={'center': "with grid's and legend"}, ylabel='Density'>

# %%
## density ploth 
df2['a'].plot.density()
df2.plot(kind='density',grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
## ggplot in plot

plt.style.use('ggplot')
df2.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#------------------------------PRATICE EXERCISE------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
data3=pd.read_csv('C:/Users/AkhilPokuri/Downloads/Refactored_Py_DS_ML_Bootcamp-master/07-Pandas-Built-in-Data-Viz/df3.csv')
data3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
data3.plot(kind='scatter',x='a',y='b',color='r',figsize=(10,4),s=50) # s is the size of ploted points
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
data3['a'].hist(color='b',grid=True,bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')
data3.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.style.use('ggplot')
data3['a'].plot.hist(bins=30,grid=False,alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data3.plot(kind='box')
# Out:
# <Axes: >

# %%
data3.plot(kind='box',column=['a','b'])
data3[['a','b']].plot.box()
# Out:
# <Axes: >

# %%
data3['d'].plot.kde(alpha=0.5)
# Out:
# <Axes: ylabel='Density'>

# %%
data3['d'].plot.kde(alpha=1,linestyle='--',linewidth=5)
# Out:
# <Axes: ylabel='Density'>

# %%
data3.plot(kind='area',xlim=30,ylim=3)
# Out:
# <Axes: >

# %%
## slicing notation
data3[1:31].plot.area(alpha=0.5)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

f=plt.figure()
data3[1:31].plot.area(alpha=0.5)
plt.legend(bbox_to_anchor=(1.50, .5))
plt.show()

# %%
f=plt.figure()
data3[1:31].plot.area(alpha=0.5)
plt.legend(loc='center right')
plt.show()
